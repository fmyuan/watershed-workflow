# %% [markdown]
# Extract points to test ELM, e.g. for purpose of debugging.

# %%
# these can be turned on for development work
# %load_ext autoreload
# %autoreload 2

# %%
import watershed_workflow.elm_domain as elm_domain
import watershed_workflow.elm_mksrfdata as elm_mksrfdata
from types import SimpleNamespace
import watershed_workflow.elm_metdata as elm_metdata
# e3sm has a xml file, in which by machine-name, DIN_LOC_ROOT is pre-defined.
# (TODO this locally or from data server)
DIN_LOC_ROOT = '/Users/f9y/e3sm_inputdata'
elm_domain.set_e3sm_input(DIN_LOC_ROOT)

# %%
set_e3sm_input('/Users/f9y/project_ww_elmats/test-e3sm-inputdata')

# Extrac a pt of domain/surfdata
allout = refine_surfdata( \
        lnd_domain_file='./domain.lnd.1765x1pt_gcrew-atselm.nc', \
        fsurdat='./surfdata_1765x1pt_simyr1850_gcrew-atselm.nc', \
        flanduse_timeseries=None, \
        userdomain='./test_extract_pts.txt', \
        domain_included=True)

print(allout)
